# %%
def turn_on_tv()->None:
    print("TV turning on...")
    print("Starting content playback...")

# Using the decorated function
turn_on_tv()
# Out:
# TV turning on...
# Starting content playback...

# %%
def smart_home_decorator(func):
    def wrapper():
        # Before execution
        print("Adjusting room lighting...")
        print("Setting optimal temperature...")

        # Original function execution
        func()

        # After execution
        print("Measuring ambient noise...")
        print("Adjusting TV volume...")

    return wrapper

@smart_home_decorator
def turn_on_tv():
    print("TV turning on...")
    print("Starting content playback...")

turn_on_tv()
# Out:
# Adjusting room lighting...
# Setting optimal temperature...
# TV turning on...
# Starting content playback...
# Measuring ambient noise...
# Adjusting TV volume...

# %%
def log_decorator(func):
    def wrapper(*args, **kwargs):
        print(f"Calling function: {func.__name__}")
        result = func(*args, **kwargs)
        print(f"Function {func.__name__} finished execution")
        return result
    return wrapper

@log_decorator
def say_hello(name):
    print(f"Hello, {name}!")

say_hello("Muhamad Qasim")
# Out:
# Calling function: say_hello
# Hello, Muhamad Qasim!
# Function say_hello finished execution

# %%
def repeat(num_times):
    def decorator(func):
        def wrapper(*args, **kwargs):
            for _ in range(num_times):
                func(*args, **kwargs)
        return wrapper
    return decorator

@repeat(10)
def greet(name):
    print(f"Hi {name}!")

greet("Muhammad Qasim")
# Out:
# Hi Muhammad Qasim!
# Hi Muhammad Qasim!
# Hi Muhammad Qasim!
# Hi Muhammad Qasim!
# Hi Muhammad Qasim!
# Hi Muhammad Qasim!
# Hi Muhammad Qasim!
# Hi Muhammad Qasim!
# Hi Muhammad Qasim!
# Hi Muhammad Qasim!

# %%
class LogDecorator:
    def __init__(self, func):
        self.func = func

    def __call__(self, *args, **kwargs):
        print(f"Calling {self.func.__name__}")
        result = self.func(*args, **kwargs)
        print(f"{self.func.__name__} finished execution")
        return result

@LogDecorator
def say_hello(name):
    print(f"Hello, {name}!")

say_hello("Alice")
# Out:
# Calling say_hello
# Hello, Alice!
# say_hello finished execution

# %%
print('1','b','c', end='\n', sep='\n')
# Out:
# 1
# b
# c

# %%
class MyClass():
  def __init__(self,name,age):
    self.name = name
    self.age = age
    self.cnic = None

  def teaching(self):
    print("Teacher is teaching")


obj1 = MyClass("Muhammad Qasim", 30)
obj1.teaching()
print(obj1.name)
# Out:
# Teacher is teaching
# Muhammad Qasim

# %%
obj1

# %%
list(dir(obj1))
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'cnic',
#  'name',
#  'teaching']

# %%
# prompt: create simple example of __format__

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __format__(self, format_spec):
        if format_spec == "short":
            return f"{self.name} ({self.age})"
        elif format_spec == "long":
            return f"Name: {self.name}, Age: {self.age}"
        else:
            return str(self)  # Default string representation


person = Person("Muhammad Qasim", 30)

print(format(person, "short"))  # Output: Alice (30)
print(format(person, "long"))  # Output: Name: Alice, Age: 30
print(person) # Output: <__main__.Person object at ...>
print(f"{person}") # Output: <__main__.Person object at ...>
# Out:
# Muhammad Qasim (30)
# Name: Muhammad Qasim, Age: 30
# <__main__.Person object at 0x7c0b08de3150>
# <__main__.Person object at 0x7c0b08de3150>

# %%
class MyClass():
  def __init__(self,name,age):
    self.name = name
    self.age = age
    self.cnic = None

  def teaching(self):
    print("Teacher is teaching")


obj1 = MyClass("Muhammad Qasim", 30)
obj1()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-8e430c0791e1> in <cell line: 0>()
#      10
#      11 obj1 = MyClass("Muhammad Qasim", 30)
# ---> 12 obj1()
#
# TypeError: 'MyClass' object is not callable

# %%
class MyClass():
  def __init__(self,name,age):
    self.name = name
    self.age = age
    self.cnic = None
    self.my_salary = 10000

  def teaching(self):
    print("Teacher is teaching")

  def __call__(self,inc=1000):
    self.my_salary += inc
    print(f"My new salary is {self.my_salary}")


obj1 = MyClass("Muhammad Qasim", 30)
obj1()
obj1()
obj1(3000)
# Out:
# My new salary is 11000
# My new salary is 12000
# My new salary is 15000

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-23-bc757c3fda29> in <cell line: 0>()
# ----> 1 1 / 0
#
# ZeroDivisionError: division by zero

# %%
open("abc.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-befa419cc814> in <cell line: 0>()
# ----> 1 open("abc.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abc.txt'

# %%
# prompt: create custom error class simple example

class InvalidInputError(Exception):
    """Custom exception for invalid input."""
    pass

def process_data(data):
    if not isinstance(data, int):
        raise InvalidInputError("Please enter intiger number here.")
    # ... further processing ...
    print("Data processed successfully.")
try:
    process_data("abc")  # This will raise the custom exception
except InvalidInputError as e:
    print(f"Error: {e}")
# Out:
# Error: Please enter intiger number here.

# %%
process_data("abc")
# Out:
# ---------------------------------------------------------------------------
# InvalidInputError                         Traceback (most recent call last)
# <ipython-input-27-0a4736930c9b> in <cell line: 0>()
# ----> 1 process_data("abc")
#
# <ipython-input-26-30f048a470fb> in process_data(data)
#       7 def process_data(data):
#       8     if not isinstance(data, int):
# ----> 9         raise InvalidInputError("Please enter intiger number here.")
#      10     # ... further processing ...
#      11     print("Data processed successfully.")
#
# InvalidInputError: Please enter intiger number here.

# %%
# prompt: __add__ create simple example

class MyNumber:
    def __init__(self, value):
        self.value = value

    def __add__(self, other):
        if isinstance(other, MyNumber):
            return MyNumber(self.value + other.value)
        elif isinstance(other, int):
            return MyNumber(self.value + other)
        else:
            return NotImplemented  # Indicate that the operation is not supported

# Example usage
num1 = MyNumber(5)
num2 = MyNumber(10)

result1 = num1 + num2  # Adding two MyNumber objects
print(result1.value)  # Output: 15

result2 = num1 + 3  # Adding a MyNumber object and an integer
print(result2.value)  # Output: 8

#result3 = num1 + "abc"  # This will return NotImplemented
#print(result3.value)
# Out:
# 15
# 8

# %%
obj1.__dict__
# Out:
# {'name': 'Muhammad Qasim', 'age': 30, 'cnic': None, 'my_salary': 15000}
